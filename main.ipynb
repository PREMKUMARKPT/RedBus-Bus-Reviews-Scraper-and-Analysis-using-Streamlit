# %%
# !pip install glob
# Out:
# ERROR: Could not find a version that satisfies the requirement glob (from versions: none)
# ERROR: No matching distribution found for glob

# %%
import glob

# %%
df1 = pd.read_csv('data1.csv')
df2 = pd.read_csv('data2.csv')
df3 = pd.read_csv('data3.csv')
df4 = pd.read_csv('data4.csv')
df5 = pd.read_csv('data5.csv')
df6 = pd.read_csv('data6.csv')
df6 = pd.read_csv('data7.csv')
df8 = pd.read_csv('data9.csv')
df9 = pd.read_csv('data9.csv')
df10 = pd.read_csv('data10.csv')
df11 = pd.read_csv('data11.csv')

# %%
import pandas as pd

# List your DataFrames
dfs = [df1, df2, df3, df4, df5, df6, df8, df10, df11]

# Concatenate into one DataFrame
merged_df = pd.concat(dfs, ignore_index=True)

# Save to a single CSV file
merged_df.to_csv('merged_output.csv', index=False)

# %%
merged_df
# Out:
#                  bus_name  amount                          about  rating
# 0             KMS Travels    ₹810              A/C Sleeper (2+1)     3.8
# 1             KMS Travels    ₹580  Bharat Benz A/C Sleeper (2+1)     4.8
# 2              A1 Travels    ₹555  Bharat Benz A/C Sleeper (2+1)     4.5
# 3        No 1 Air Travels    ₹600  Bharat Benz A/C Sleeper (2+1)     4.3
# 4    Jihan luxury travels    ₹600              A/C Sleeper (2+1)     3.7
# ..                    ...     ...                            ...     ...
# 164         Svkdt travels  ₹1,900              A/C Sleeper (2+1)     4.1
# 165      Sri Auto Travels    ₹879              A/C Sleeper (2+1)     2.8
# 166      Sri Auto Travels    ₹999              A/C Sleeper (2+1)     2.8
# 167  Rathimeena Travels C    ₹534              A/C Sleeper (2+1)     4.5
# 168  Rathimeena Travels C    ₹534              A/C Sleeper (2+1)     4.3
#
# [169 rows x 4 columns]

# %%
df = merged_df

# %%
df
# Out:
#                  bus_name  amount                          about  rating
# 0             KMS Travels    ₹810              A/C Sleeper (2+1)     3.8
# 1             KMS Travels    ₹580  Bharat Benz A/C Sleeper (2+1)     4.8
# 2              A1 Travels    ₹555  Bharat Benz A/C Sleeper (2+1)     4.5
# 3        No 1 Air Travels    ₹600  Bharat Benz A/C Sleeper (2+1)     4.3
# 4    Jihan luxury travels    ₹600              A/C Sleeper (2+1)     3.7
# ..                    ...     ...                            ...     ...
# 164         Svkdt travels  ₹1,900              A/C Sleeper (2+1)     4.1
# 165      Sri Auto Travels    ₹879              A/C Sleeper (2+1)     2.8
# 166      Sri Auto Travels    ₹999              A/C Sleeper (2+1)     2.8
# 167  Rathimeena Travels C    ₹534              A/C Sleeper (2+1)     4.5
# 168  Rathimeena Travels C    ₹534              A/C Sleeper (2+1)     4.3
#
# [169 rows x 4 columns]

# %%
# we will do some preprocessing

df
# Out:
#                  bus_name  amount                          about  rating
# 0             KMS Travels    ₹810              A/C Sleeper (2+1)     3.8
# 1             KMS Travels    ₹580  Bharat Benz A/C Sleeper (2+1)     4.8
# 2              A1 Travels    ₹555  Bharat Benz A/C Sleeper (2+1)     4.5
# 3        No 1 Air Travels    ₹600  Bharat Benz A/C Sleeper (2+1)     4.3
# 4    Jihan luxury travels    ₹600              A/C Sleeper (2+1)     3.7
# ..                    ...     ...                            ...     ...
# 164         Svkdt travels  ₹1,900              A/C Sleeper (2+1)     4.1
# 165      Sri Auto Travels    ₹879              A/C Sleeper (2+1)     2.8
# 166      Sri Auto Travels    ₹999              A/C Sleeper (2+1)     2.8
# 167  Rathimeena Travels C    ₹534              A/C Sleeper (2+1)     4.5
# 168  Rathimeena Travels C    ₹534              A/C Sleeper (2+1)     4.3
#
# [169 rows x 4 columns]

# %%
df
# Out:
#                  bus_name  amount                          about  rating
# 0             KMS Travels    ₹810              A/C Sleeper (2+1)     3.8
# 1             KMS Travels    ₹580  Bharat Benz A/C Sleeper (2+1)     4.8
# 2              A1 Travels    ₹555  Bharat Benz A/C Sleeper (2+1)     4.5
# 3        No 1 Air Travels    ₹600  Bharat Benz A/C Sleeper (2+1)     4.3
# 4    Jihan luxury travels    ₹600              A/C Sleeper (2+1)     3.7
# ..                    ...     ...                            ...     ...
# 164         Svkdt travels  ₹1,900              A/C Sleeper (2+1)     4.1
# 165      Sri Auto Travels    ₹879              A/C Sleeper (2+1)     2.8
# 166      Sri Auto Travels    ₹999              A/C Sleeper (2+1)     2.8
# 167  Rathimeena Travels C    ₹534              A/C Sleeper (2+1)     4.5
# 168  Rathimeena Travels C    ₹534              A/C Sleeper (2+1)     4.3
#
# [169 rows x 4 columns]

# %%
df.columns
# Out:
# Index(['bus_name', 'amount', 'about', 'rating'], dtype='object')

# %%
pip install pymysql

# %%
engine = create_engine(
    "mysql+pymysql://7Z3SRE1xmB2xsHv.root:Rloj46Ewjuq6O8SY@gateway01.ap-southeast-1.prod.aws.tidbcloud.com:4000/PROJECT_2"
)

# %%
data = pd.read_csv("df.csv")
data
# Out:
#                  bus_name  amount                          about  rating
# 0             KMS Travels    ₹810              A/C Sleeper (2+1)     3.8
# 1             KMS Travels    ₹580  Bharat Benz A/C Sleeper (2+1)     4.8
# 2              A1 Travels    ₹555  Bharat Benz A/C Sleeper (2+1)     4.5
# 3        No 1 Air Travels    ₹600  Bharat Benz A/C Sleeper (2+1)     4.3
# 4    Jihan luxury travels    ₹600              A/C Sleeper (2+1)     3.7
# ..                    ...     ...                            ...     ...
# 164         Svkdt travels  ₹1,900              A/C Sleeper (2+1)     4.1
# 165      Sri Auto Travels    ₹879              A/C Sleeper (2+1)     2.8
# 166      Sri Auto Travels    ₹999              A/C Sleeper (2+1)     2.8
# 167  Rathimeena Travels C    ₹534              A/C Sleeper (2+1)     4.5
# 168  Rathimeena Travels C    ₹534              A/C Sleeper (2+1)     4.3
#
# [169 rows x 4 columns]

# %%
import pandas as pd
from sqlalchemy import create_engine

# Step 1: Load your dataset into a pandas DataFrame
data = pd.read_csv("df.csv")  # Replace with your CSV path

# Step 2: Create a secure SQLAlchemy connection to TiDB (with SSL enabled)
engine = create_engine(
    "mysql+pymysql://7Z3SRE1xmB2xsHv.root:Rloj46Ewjuq6O8SY@gateway01.ap-southeast-1.prod.aws.tidbcloud.com:4000/PROJECT_2?ssl_ca=true"
)

# %%
import pandas as pd
from sqlalchemy import create_engine

# ✅ Establish connection with TiDB
engine = create_engine(
    "mysql+pymysql://7Z3SRE1xmB2xsHv.root:Rloj46Ewjuq6O8SY@gateway01.ap-southeast-1.prod.aws.tidbcloud.com:4000/PROJECT_2?ssl_ca=true"
)

# ✅ Correct CSV path
data = pd.read_csv("df.csv")

# ✅ Upload to TiDB
data.to_sql('bus_data1', engine, if_exists='replace', index=False)

print("✅ Data uploaded successfully!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[232], line 13
#      10 data = pd.read_csv("df.csv")
#      12 # ✅ Upload to TiDB
# ---> 13 data.to_sql('bus_data1', engine, if_exists='replace', index=False)
#      15 print("✅ Data uploaded successfully!")
#
# File c:\Users\Prem Kumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
import os
print(os.listdir())  # Shows files/folders in the current working directory
# Out:
# ['Anaconda Navigator.lnk', 'data.1.ipynb', 'data1.csv', 'data10.csv', 'data10.ipynb', 'data11.csv', 'data2.csv', 'data2.ipynb', 'data3.csv', 'data3.ipynb', 'data4.csv', 'data4.ipynb', 'data5.csv', 'data5.ipynb', 'data6.csv', 'data6.ipynb', 'data7.csv', 'data7.ipynb', 'data8', 'data8.ipynb', 'data9.csv', 'data9.ipynb', 'df', 'df.csv', 'main.ipynb', 'merged_output.csv', 'seleninum.ipynb']

# %%
import pandas as pd
from sqlalchemy import create_engine

# ✅ Connect to TiDB
engine = create_engine(
    "mysql+pymysql://7Z3SRE1xmB2xsHv.root:Rloj46Ewjuq6O8SY@gateway01.ap-southeast-1.prod.aws.tidbcloud.com:4000/PROJECT_2?ssl_ca=true"
)

# ✅ Corrected CSV path
data = pd.read_csv("df/df.csv")

# ✅ Upload to SQL
data.to_sql('bus_data1', engine, if_exists='replace', index=False)

print("✅ Data uploaded successfully!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[236], line 10
#       5 engine = create_engine(
#       6     "mysql+pymysql://7Z3SRE1xmB2xsHv.root:Rloj46Ewjuq6O8SY@gateway01.ap-southeast-1.prod.aws.tidbcloud.com:4000/PROJECT_2?ssl_ca=true"
#       7 )
#       9 # ✅ Corrected CSV path
# ---> 10 data = pd.read_csv("df/df.csv")
#      12 # ✅ Upload to SQL
#      13 data.to_sql('bus_data1', engine, if_exists='replace', index=False)
#
# ...

# %%
# import necessary packages
import pandas
import psycopg2
from sqlalchemy import create_engine

# establish connection with the database
engine = create_engine(
    "mysql+pymysql://7Z3SRE1xmB2xsHv.root:Rloj46Ewjuq6O8SY@gateway01.ap-southeast-1.prod.aws.tidbcloud.com:4000/PROJECT_2?ssl_ca=true"
)

# read the pandas dataframe
data = pandas.read_csv("df.csv")

# connect the pandas dataframe with postgresql table
data.to_sql('bus_data1', engine, if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[228], line 15
#      12 data = pandas.read_csv("df.csv")
#      14 # connect the pandas dataframe with postgresql table
# ---> 15 data.to_sql('bus_data1', engine, if_exists='replace')
#
# File c:\Users\Prem Kumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
data = pd.read_csv("df.csv")

# %%
import os
print(os.path.exists("C:/Users/Prem Kumar/Desktop/bus_data.csv"))
# Out:
# False

# %%
pip install psycopg2
# Out:
# ...
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    --------------------------- ------------ 0.8/1.2 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 5.2 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# HOST:

# gateway01.ap-southeast-1.prod.aws.tidbcloud.com

# PORT:

# 4000

# USERNAME:

# 7Z3SRE1xmB2xsHv.root

# PASSWORD:

# Rloj46Ewjuq6O8SY

# DATABASE:

# PROJECT_2

# %%
df
# Out:
#                  bus_name  amount                          about  rating
# 0             KMS Travels    ₹810              A/C Sleeper (2+1)     3.8
# 1             KMS Travels    ₹580  Bharat Benz A/C Sleeper (2+1)     4.8
# 2              A1 Travels    ₹555  Bharat Benz A/C Sleeper (2+1)     4.5
# 3        No 1 Air Travels    ₹600  Bharat Benz A/C Sleeper (2+1)     4.3
# 4    Jihan luxury travels    ₹600              A/C Sleeper (2+1)     3.7
# ..                    ...     ...                            ...     ...
# 164         Svkdt travels  ₹1,900              A/C Sleeper (2+1)     4.1
# 165      Sri Auto Travels    ₹879              A/C Sleeper (2+1)     2.8
# 166      Sri Auto Travels    ₹999              A/C Sleeper (2+1)     2.8
# 167  Rathimeena Travels C    ₹534              A/C Sleeper (2+1)     4.5
# 168  Rathimeena Travels C    ₹534              A/C Sleeper (2+1)     4.3
#
# [169 rows x 4 columns]
